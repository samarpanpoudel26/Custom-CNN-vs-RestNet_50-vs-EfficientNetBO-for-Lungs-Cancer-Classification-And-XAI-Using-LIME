# %%
import os
import tensorflow as tf
import keras
import cv2
from keras.applications import inception_v3 as inc_net
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
#Loading model
model = tf.keras.models.load_model("/Users/samarpanpoudel/Desktop/model 1/saved_models/model1.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
IMG_SIZE = 256  

def preprocess_image(img):
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img = img.astype("float32") / 255.0
    return img

# %%
def predict_fn(images):
    images = np.array([preprocess_image(img) for img in images])
    return model.predict(images)

# %%
image_path = "/Users/samarpanpoudel/Desktop/model 1/Dataset/Negative/LUNG MRI-NC (29).png"
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
from lime import lime_image
from skimage.segmentation import mark_boundaries

# %%
explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(
    image=image,
    classifier_fn=predict_fn,
    top_labels=1,
    hide_color=0,
    num_samples=1000
)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   2%|▏         | 19/1000 [00:00<00:14, 68.67it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   3%|▎         | 27/1000 [00:00<00:17, 56.74it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#   3%|▎         | 34/1000 [00:00<00:18, 52.65it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   5%|▍         | 49/1000 [00:00<00:16, 58.34it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#   6%|▌         | 56/1000 [00:01<00:17, 52.85it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   6%|▌         | 62/1000 [00:01<00:19, 48.80it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   8%|▊         | 78/1000 [00:01<00:17, 54.18it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   8%|▊         | 84/1000 [00:01<00:18, 49.76it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#  10%|▉         | 98/1000 [00:01<00:16, 54.88it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  10%|█         | 104/1000 [00:01<00:17, 50.68it/s]
# ...

# %%
predicted_class = np.argmax(predict_fn([image]))

temp, mask = explanation.get_image_and_mask(
    label=predicted_class,
    positive_only=True,
    num_features=10,
    hide_rest=False
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
plt.figure(figsize=(6, 6))
plt.imshow(mark_boundaries(temp, mask))
plt.axis("off")
plt.savefig("003.png")
plt.show()
