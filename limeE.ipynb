# %%
import os
import tensorflow as tf
import keras
import cv2
from keras.applications import inception_v3 as inc_net
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
#Loading model
model = tf.keras.models.load_model("/Users/samarpanpoudel/Desktop/EfficientNet-BO/saved_models/efficientnet_bo.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
IMG_SIZE = 256  

def preprocess_image(img):
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    return img

# %%
def predict_fn(images):
    images = np.array([preprocess_image(img) for img in images])
    return model.predict(images)

# %%
image_path = "/Users/samarpanpoudel/Desktop/model 1/failure_dataset/images/006.png"
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
from lime import lime_image
from skimage.segmentation import mark_boundaries

# %%
explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(
    image=image,
    classifier_fn=predict_fn,
    top_labels=1,
    hide_color=0,
    num_samples=1000
)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step
#   1%|          | 10/1000 [00:00<01:17, 12.78it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#   2%|▏         | 20/1000 [00:00<00:39, 24.57it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#   3%|▎         | 30/1000 [00:01<00:28, 33.87it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#   4%|▍         | 40/1000 [00:01<00:22, 42.67it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#   5%|▌         | 50/1000 [00:01<00:19, 49.10it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#   6%|▌         | 60/1000 [00:01<00:17, 53.22it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
#   7%|▋         | 70/1000 [00:01<00:16, 54.77it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#   8%|▊         | 80/1000 [00:01<00:15, 58.01it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#   9%|▉         | 90/1000 [00:02<00:14, 60.95it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#  10%|█         | 100/1000 [00:02<00:14, 63.03it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
#  11%|█         | 110/1000 [00:02<00:13, 64.14it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#  12%|█▏        | 120/1000 [00:02<00:13, 65.50it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#  13%|█▎        | 130/1000 [00:02<00:13, 65.99it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
#  14%|█▍        | 140/1000 [00:02<00:12, 66.75it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#  15%|█▌        | 150/1000 [00:02<00:12, 67.12it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#  16%|█▌        | 160/1000 [00:03<00:12, 67.77it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#  17%|█▋        | 170/1000 [00:03<00:12, 67.52it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#  18%|█▊        | 180/1000 [00:03<00:12, 64.35it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#  19%|█▉        | 190/1000 [00:03<00:12, 64.82it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#  20%|██        | 200/1000 [00:03<00:12, 65.32it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#  21%|██        | 210/1000 [00:03<00:12, 65.35it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#  22%|██▏       | 220/1000 [00:03<00:11, 65.80it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  23%|██▎       | 230/1000 [00:04<00:11, 65.62it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#  24%|██▍       | 240/1000 [00:04<00:11, 66.00it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#  25%|██▌       | 250/1000 [00:04<00:11, 66.70it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#  26%|██▌       | 260/1000 [00:04<00:10, 67.34it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#  27%|██▋       | 270/1000 [00:04<00:11, 65.84it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  28%|██▊       | 280/1000 [00:04<00:11, 65.34it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
#  29%|██▉       | 290/1000 [00:05<00:10, 65.99it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  30%|███       | 300/1000 [00:05<00:10, 65.42it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  31%|███       | 310/1000 [00:05<00:11, 62.58it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#  32%|███▏      | 320/1000 [00:05<00:10, 63.01it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#  33%|███▎      | 330/1000 [00:05<00:10, 63.72it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#  34%|███▍      | 340/1000 [00:05<00:10, 64.07it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#  35%|███▌      | 350/1000 [00:05<00:10, 64.77it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  36%|███▌      | 360/1000 [00:06<00:09, 65.05it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#  37%|███▋      | 370/1000 [00:06<00:09, 64.66it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#  38%|███▊      | 380/1000 [00:06<00:09, 63.50it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
#  39%|███▉      | 390/1000 [00:06<00:09, 62.92it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
#  40%|████      | 400/1000 [00:06<00:09, 61.71it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
#  41%|████      | 410/1000 [00:06<00:09, 61.13it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
#  42%|████▏     | 420/1000 [00:07<00:09, 60.62it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
#  43%|████▎     | 430/1000 [00:07<00:09, 57.03it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
#  44%|████▍     | 440/1000 [00:07<00:09, 58.12it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  45%|████▌     | 450/1000 [00:07<00:09, 59.71it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  46%|████▌     | 460/1000 [00:07<00:08, 61.11it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  47%|████▋     | 470/1000 [00:07<00:08, 61.57it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  48%|████▊     | 480/1000 [00:08<00:08, 62.42it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#  49%|████▉     | 490/1000 [00:08<00:08, 63.27it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#  50%|█████     | 500/1000 [00:08<00:07, 63.46it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  51%|█████     | 510/1000 [00:08<00:07, 63.70it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  52%|█████▏    | 520/1000 [00:08<00:07, 64.08it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  53%|█████▎    | 530/1000 [00:08<00:07, 64.03it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#  54%|█████▍    | 540/1000 [00:09<00:07, 63.57it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  55%|█████▌    | 550/1000 [00:09<00:07, 63.85it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#  56%|█████▌    | 560/1000 [00:09<00:06, 64.70it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  57%|█████▋    | 570/1000 [00:09<00:08, 49.53it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#  58%|█████▊    | 580/1000 [00:09<00:07, 53.89it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#  59%|█████▉    | 590/1000 [00:09<00:07, 56.86it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#  60%|██████    | 600/1000 [00:10<00:06, 59.51it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#  61%|██████    | 610/1000 [00:10<00:06, 61.27it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#  62%|██████▏   | 620/1000 [00:10<00:06, 62.26it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  63%|██████▎   | 630/1000 [00:10<00:05, 62.98it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#  64%|██████▍   | 640/1000 [00:10<00:05, 62.99it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  65%|██████▌   | 650/1000 [00:10<00:05, 62.12it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#  66%|██████▌   | 660/1000 [00:11<00:05, 62.30it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#  67%|██████▋   | 670/1000 [00:11<00:05, 62.43it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  68%|██████▊   | 680/1000 [00:11<00:05, 62.94it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#  69%|██████▉   | 690/1000 [00:11<00:04, 63.32it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#  70%|███████   | 700/1000 [00:11<00:04, 63.97it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#  71%|███████   | 710/1000 [00:11<00:04, 61.85it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  72%|███████▏  | 720/1000 [00:11<00:04, 62.28it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#  73%|███████▎  | 730/1000 [00:12<00:04, 62.53it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  74%|███████▍  | 740/1000 [00:12<00:04, 62.80it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#  75%|███████▌  | 750/1000 [00:12<00:03, 62.99it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  76%|███████▌  | 760/1000 [00:12<00:03, 63.17it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  77%|███████▋  | 770/1000 [00:12<00:03, 63.13it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#  78%|███████▊  | 780/1000 [00:12<00:03, 62.83it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#  79%|███████▉  | 790/1000 [00:13<00:03, 62.73it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#  80%|████████  | 800/1000 [00:13<00:03, 62.58it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#  81%|████████  | 810/1000 [00:13<00:03, 63.14it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  82%|████████▏ | 820/1000 [00:13<00:02, 63.62it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  83%|████████▎ | 830/1000 [00:13<00:02, 63.53it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
#  84%|████████▍ | 840/1000 [00:13<00:02, 60.94it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#  85%|████████▌ | 850/1000 [00:14<00:02, 61.44it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#  86%|████████▌ | 860/1000 [00:14<00:02, 61.68it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
#  87%|████████▋ | 870/1000 [00:14<00:02, 62.42it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#  88%|████████▊ | 880/1000 [00:14<00:01, 61.66it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  89%|████████▉ | 890/1000 [00:14<00:01, 61.78it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  90%|█████████ | 900/1000 [00:14<00:01, 61.85it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#  91%|█████████ | 910/1000 [00:15<00:01, 61.99it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#  92%|█████████▏| 920/1000 [00:15<00:01, 62.34it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
#  93%|█████████▎| 930/1000 [00:15<00:01, 62.03it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#  94%|█████████▍| 940/1000 [00:15<00:00, 62.41it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
#  95%|█████████▌| 950/1000 [00:15<00:00, 56.86it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
#  96%|█████████▌| 960/1000 [00:15<00:00, 57.93it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
#  97%|█████████▋| 970/1000 [00:16<00:00, 59.67it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
#  98%|█████████▊| 980/1000 [00:16<00:00, 58.61it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
#  99%|█████████▉| 990/1000 [00:16<00:00, 59.61it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 100%|██████████| 1000/1000 [00:16<00:00, 60.41it/s]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_base.py:280: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_

# %%
import numpy as np

def get_lime_importance_vector(explanation, label, positive_only=False):
    # Total number of superpixels
    segments = explanation.segments
    num_superpixels = np.unique(segments).shape[0]
    
    # Initialize vector with zeros
    importance_vector = np.zeros(num_superpixels)
    
    # Get list of (superpixel_id, weight)
    local_exp = explanation.local_exp[label]
    
    for superpixel_id, weight in local_exp:
        
        if positive_only:
            weight = max(0, weight)
        
        importance_vector[superpixel_id] = weight
    
    return importance_vector

# %%
label = explanation.top_labels[0]

vector = get_lime_importance_vector(explanation, label)

print(vector.shape)
# Out:
# (37,)

# %%
predicted_class = np.argmax(predict_fn([image]))

temp, mask = explanation.get_image_and_mask(
    label=predicted_class,
    positive_only=True,
    num_features=10,
    hide_rest=False
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step

# %%
plt.figure(figsize=(6, 6))
plt.imshow(mark_boundaries(temp, mask))
plt.axis("off")
#plt.savefig("004.png")
plt.show()
